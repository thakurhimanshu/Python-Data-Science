# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/165.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 165.5/165.5 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.6/8.0 MB 12.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.4/8.0 MB 12.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.0 MB 13.8 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 13.0 MB/s eta 0:00:01
#    ------------------ --------------------- 3.8/8.0 MB 13.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.3/8.0 MB 14.6 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/8.0 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 17.3 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax=plt.subplots(nrows=1,ncols=2,figsize=(15,5)) 
t=np.arange(-10,10,.1)
sine=np.sin(t)
cosine=np.cos(t)
print(t)
print(sine)
print(cosine)
# print(ax[0]) #ax==numpy
ax[0].plot(t,sine,label='sine',color='red',linestyle='',marker='o')
ax[1].plot(t,cosine,label='cosine',color='blue')
plt.show()
plt.savefig('sine_cosine.png',dpi=200)
# Out:
# [-1.00000000e+01 -9.90000000e+00 -9.80000000e+00 -9.70000000e+00
#  -9.60000000e+00 -9.50000000e+00 -9.40000000e+00 -9.30000000e+00
#  -9.20000000e+00 -9.10000000e+00 -9.00000000e+00 -8.90000000e+00
#  -8.80000000e+00 -8.70000000e+00 -8.60000000e+00 -8.50000000e+00
#  -8.40000000e+00 -8.30000000e+00 -8.20000000e+00 -8.10000000e+00
#  -8.00000000e+00 -7.90000000e+00 -7.80000000e+00 -7.70000000e+00
#  -7.60000000e+00 -7.50000000e+00 -7.40000000e+00 -7.30000000e+00
#  -7.20000000e+00 -7.10000000e+00 -7.00000000e+00 -6.90000000e+00
#  -6.80000000e+00 -6.70000000e+00 -6.60000000e+00 -6.50000000e+00
#  -6.40000000e+00 -6.30000000e+00 -6.20000000e+00 -6.10000000e+00
#  -6.00000000e+00 -5.90000000e+00 -5.80000000e+00 -5.70000000e+00
#  -5.60000000e+00 -5.50000000e+00 -5.40000000e+00 -5.30000000e+00
#  -5.20000000e+00 -5.10000000e+00 -5.00000000e+00 -4.90000000e+00
#  -4.80000000e+00 -4.70000000e+00 -4.60000000e+00 -4.50000000e+00
# ...

# %% [markdown]
# plt.plot--> line graphs
# plt.bar-->bar graph
# plt.pie-->pie chart
# plt.scatter-->scatter
# plt.hist-->histogram

# %%
fig,((g1,g2),(g3,g4)) =plt.subplots(nrows=2,ncols=2,figsize=(10,10)) 
g1.bar([1,2,3,4,5,6,7],[5.1,4.5,3.8,5.9,7,6,3.5])


days=['sun','mon','tue','wed','thu','fri','sat']
sale=[150,500,249,355,788,650,777]
profit=[5000,6500,4500,3500,1450,5500,2500]
g2.hist(profit ,bins=[0,1000,1500,2500,3500,4500,5000,6000],color='green',edgecolor='black') #hist: univariant(single)

g3.pie(sale,labels=days,autopct='%.1f%%', explode=(0,0,0,0,0,0,0),wedgeprops={'width':1}) #bi-variant


x=np.random.normal(0,1,500)
y=np.random.normal(0,1,500)
g4.scatter(x,y,color='r')
plt.show()

# %%
plt.stem(sale)
# Out:
# <StemContainer object of 3 artists>
